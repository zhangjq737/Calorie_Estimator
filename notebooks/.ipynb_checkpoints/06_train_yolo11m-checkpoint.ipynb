# %%
# Cell 1: Setup training
from ultralytics import YOLO
from pathlib import Path

# Paths
data_yaml = Path.home() / "calorie_estimator" / "datasets" / "food101_yolo" / "data.yaml"
output_dir = Path.home() / "calorie_estimator" / "models"
output_dir.mkdir(exist_ok=True)

# Load pre-trained model
model = YOLO('yolo11m.pt')

target_class = 'steak'  # or 'sushi', 'pizza', etc.

print(f"Model: YOLOv11m")
print(f"Dataset: {data_yaml}")
print(f"Output: {output_dir}")
print(f"Device: {model.device}")  # Should show 'mps' for Mac M4 Pro
# Out:
# Model: YOLOv11m
# Dataset: /Users/jasonzhang/calorie_estimator/datasets/food101_yolo/data.yaml
# Output: /Users/jasonzhang/calorie_estimator/models
# Device: cpu

# %%
# Cell 2: Start training

results = model.train(
    data=str(Path.home() / "calorie_estimator" / "datasets" / "food-101-steak" / "data.yaml"),
    
    epochs=50,
    batch=16,               # Can use larger batch with 1 class
    imgsz=640,
    workers=4,
    
    device='mps',
    cache='ram',            # 750 images fit easily in RAM
    
    pretrained=True,
    freeze=0,
    
    optimizer='AdamW',
    lr0=0.001,
    lrf=0.0001,
    
    patience=15,
    save_period=10,
    
    project=str(output_dir),
    name=f'food101_{target_class}',
)
print("\n" + "="*60)
print("Training Complete!")
print("="*60)
print(f"Best model saved at: {output_dir / 'food101_yolo11m' / 'weights' / 'best.pt'}")
# Out:
# New https://pypi.org/project/ultralytics/8.3.222 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.13.9 torch-2.9.0 MPS (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=ram, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/jasonzhang/calorie_estimator/datasets/food-101-single/data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=0, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.0001, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_pizza, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/Users/jasonzhang/calorie_estimator/models, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/jasonzhang/calorie_estimator/models/food101_pizza, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,179 parameters, 9,428,163 gradients, 21.5 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 238.2±126.5 MB/s, size: 54.5 KB)
# train: Scanning /Users/jasonzhang/calorie_estimator/datasets/food-101-single/labels/train... 750 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 5.5Kit/s 0.1s0.1s
# train: New cache created: /Users/jasonzhang/calorie_estimator/datasets/food-101-single/labels/train.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.7GB RAM): 100% ━━━━━━━━━━━━ 750/750 5.2Kit/s 0.1s0.2s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 318.5±55.4 MB/s, size: 56.8 KB)
# val: Scanning /Users/jasonzhang/calorie_estimator/datasets/food-101-single/labels/val... 250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 5.3Kit/s 0.0s
# val: New cache created: /Users/jasonzhang/calorie_estimator/datasets/food-101-single/labels/val.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.3GB RAM): 100% ━━━━━━━━━━━━ 250/250 4.9Kit/s 0.1s
# Plotting labels to /Users/jasonzhang/calorie_estimator/models/food101_pizza/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/jasonzhang/calorie_estimator/models/food101_pizza
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      9.87G     0.2177     0.5285     0.9898         46        640: 100% ━━━━━━━━━━━━ 47/47 0.8it/s 56.8s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.4it/s 18.5s1.6ss
#                    all        250        250       0.83      0.996      0.933      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      8.47G     0.2067     0.2867     0.9669         40        640: 100% ━━━━━━━━━━━━ 47/47 1.0it/s 48.9s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.9it/s 9.3s1.2ss
#                    all        250        250      0.988          1      0.994      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      8.47G     0.2174     0.3134     0.9608         45        640: 100% ━━━━━━━━━━━━ 47/47 1.0it/s 49.2s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.4it/s 20.1s1.9ss
#                    all        250        250      0.454      0.376      0.306     0.0747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      8.48G     0.1966     0.2616     0.9461         42        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 49.5s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.9it/s 9.2s1.3ss
#                    all        250        250      0.667      0.848      0.798      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      8.37G     0.1943     0.2712     0.9411         40        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 49.7s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.1s1.2ss
#                    all        250        250      0.967      0.968      0.978      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50       8.4G     0.1808     0.2551     0.9361         45        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 50.8s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.9it/s 9.3s1.3ss
#                    all        250        250      0.967      0.952      0.988      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      8.38G     0.1776     0.2459     0.9309         44        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 50.3s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.945      0.971      0.991      0.965
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      8.48G     0.1687     0.2287     0.9337         47        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 50.6s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.8s1.1ss
#                    all        250        250      0.942      0.988      0.992        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      8.47G     0.1557     0.2208      0.919         44        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 50.7s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.984      0.998      0.995      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50       8.4G       0.15     0.2115     0.9219         40        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 51.9s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250      0.959      0.784      0.905      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      8.47G     0.1444     0.2166     0.9212         42        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 53.1s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.876      0.932      0.962      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      8.47G     0.1356     0.2004     0.9155         39        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 52.8s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.994          1      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      8.47G     0.1288     0.1955     0.9109         48        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 52.5s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250      0.959      0.944      0.978      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50       8.4G      0.122     0.1803     0.9096         47        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 52.2s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.8s1.1ss
#                    all        250        250      0.992      0.984      0.994      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      8.37G     0.1161     0.1795     0.9076         38        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.2s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.1ss
#                    all        250        250      0.994          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      8.61G     0.1198     0.1792     0.9067         43        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 52.6s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.996      0.996      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      8.47G     0.1103     0.1669     0.9066         45        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 53.3s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250       0.98      0.996      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      8.39G     0.1096     0.1656     0.9034         43        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.0s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.996          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      8.47G     0.1069     0.1583       0.89         40        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 53.3s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.1s1.2ss
#                    all        250        250      0.995          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      8.47G     0.1076     0.1565     0.8938         45        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.1s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250      0.998      0.996      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      8.61G    0.09602     0.1535     0.8931         43        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 53.8s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250      0.996      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      8.48G    0.09123      0.151     0.8945         41        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.3s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.994          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      8.39G    0.09413     0.1506     0.8884         40        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.9s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250      0.995          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      8.61G    0.08678     0.1442     0.8943         38        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.7s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      8.48G    0.08969     0.1575     0.8955         45        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.7s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250          1          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      8.47G    0.09032     0.1473     0.8948         41        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 55.1s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      8.47G    0.08541     0.1401     0.8962         44        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.7s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.1s1.2ss
#                    all        250        250      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      8.47G    0.08788     0.1373     0.8993         51        640: 100% ━━━━━━━━━━━━ 47/47 0.8it/s 55.6s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.8s1.1ss
#                    all        250        250      0.995          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      8.43G    0.08047     0.1299     0.8951         45        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.8s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 8.0s1.2ss
#                    all        250        250      0.996          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      8.39G    0.07938     0.1305     0.8855         45        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 55.3s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.7s1.1ss
#                    all        250        250      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      8.61G    0.07585       0.13     0.8877         45        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 55.0s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250      0.988      0.993      0.995      0.971
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      8.38G    0.07201     0.1293     0.8854         44        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.8s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.1ss
#                    all        250        250      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      8.38G    0.07662     0.1359     0.8883         40        640: 100% ━━━━━━━━━━━━ 47/47 0.8it/s 55.4s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.7s1.1ss
#                    all        250        250      0.994      0.988      0.995      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50       8.4G    0.07437       0.13     0.8874         40        640: 100% ━━━━━━━━━━━━ 47/47 0.9it/s 54.3s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.2ss
#                    all        250        250      0.987      0.992      0.994      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      8.37G    0.06768     0.1185     0.8873         46        640: 100% ━━━━━━━━━━━━ 47/47 0.8it/s 56.5s1.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.8s1.1ss
#                    all        250        250      0.996      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      8.46G    0.07098     0.1237     0.8895         45        640: 100% ━━━━━━━━━━━━ 47/47 0.8it/s 55.5s1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.0it/s 7.9s1.1ss
#                    all        250        250      0.996          1      0.995      0.994
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 21, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 36 epochs completed in 0.625 hours.
# Optimizer stripped from /Users/jasonzhang/calorie_estimator/models/food101_pizza/weights/last.pt, 19.2MB
# Optimizer stripped from /Users/jasonzhang/calorie_estimator/models/food101_pizza/weights/best.pt, 19.2MB
#
# Validating /Users/jasonzhang/calorie_estimator/models/food101_pizza/weights/best.pt...
# Ultralytics 8.3.221 🚀 Python-3.13.9 torch-2.9.0 MPS (Apple M4 Pro)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.8it/s 10.1s.7ss
#                    all        250        250      0.996      0.999      0.995      0.995
# Speed: 0.1ms preprocess, 22.9ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /Users/jasonzhang/calorie_estimator/models/food101_pizza
#
# ============================================================
# Training Complete!
# ============================================================
# Best model saved at: /Users/jasonzhang/calorie_estimator/models/food101_yolo11m/weights/best.pt
