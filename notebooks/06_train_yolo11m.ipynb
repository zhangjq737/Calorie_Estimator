# %%
# Cell 1: Setup training
from ultralytics import YOLO
from pathlib import Path

# Paths
data_yaml = Path.home() / "calorie_estimator" / "datasets" / "food101_yolo" / "data.yaml"
output_dir = Path.home() / "calorie_estimator" / "models"
output_dir.mkdir(exist_ok=True)

# Load pre-trained model
model = YOLO('yolo11m.pt')

target_class = 'steak'  # or 'sushi', 'pizza', etc.

print(f"Model: YOLOv11m")
print(f"Dataset: {data_yaml}")
print(f"Output: {output_dir}")
print(f"Device: {model.device}")  # Should show 'mps' for Mac M4 Pro
# Out:
# Model: YOLOv11m
# Dataset: /Users/jasonzhang/calorie_estimator/datasets/food101_yolo/data.yaml
# Output: /Users/jasonzhang/calorie_estimator/models
# Device: cpu

# %%
# Cell 2: Start training

results = model.train(
    data=str(Path.home() / "calorie_estimator" / "datasets" / "food-101-steak" / "data.yaml"),
    
    epochs=50,
    batch=16,               # Can use larger batch with 1 class
    imgsz=640,
    workers=4,
    
    device='mps',
    cache='ram',            # 750 images fit easily in RAM
    
    pretrained=True,
    freeze=0,
    
    optimizer='AdamW',
    lr0=0.001,
    lrf=0.0001,
    
    patience=15,
    save_period=10,
    
    project=str(output_dir),
    name=f'food101_{target_class}',
)
print("\n" + "="*60)
print("Training Complete!")
print("="*60)
# Out:
# New https://pypi.org/project/ultralytics/8.3.222 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.13.9 torch-2.9.0 MPS (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=ram, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/jasonzhang/calorie_estimator/datasets/food-101-steak/data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=0, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.0001, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_steak, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/Users/jasonzhang/calorie_estimator/models, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/jasonzhang/calorie_estimator/models/food101_steak, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,053,779 parameters, 20,053,763 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 311.6±84.1 MB/s, size: 47.6 KB)
# train: Scanning /Users/jasonzhang/calorie_estimator/datasets/food-101-steak/labels/train... 750 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 5.6Kit/s 0.1s0.1s
# train: New cache created: /Users/jasonzhang/calorie_estimator/datasets/food-101-steak/labels/train.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.8GB RAM): 100% ━━━━━━━━━━━━ 750/750 4.9Kit/s 0.2s0.1s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 353.2±47.9 MB/s, size: 54.7 KB)
# val: Scanning /Users/jasonzhang/calorie_estimator/datasets/food-101-steak/labels/val... 250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 5.3Kit/s 0.0s
# val: New cache created: /Users/jasonzhang/calorie_estimator/datasets/food-101-steak/labels/val.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.3GB RAM): 100% ━━━━━━━━━━━━ 250/250 5.3Kit/s 0.0s
# Plotting labels to /Users/jasonzhang/calorie_estimator/models/food101_steak/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/jasonzhang/calorie_estimator/models/food101_steak
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      16.8G     0.2459     0.4384      1.006         47        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:172.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.4it/s 17.8s2.1ss
#                    all        250        250      0.859      0.855      0.908      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      16.7G     0.2454     0.3234     0.9843         40        640: 100% ━━━━━━━━━━━━ 47/47 0.4it/s 2:113.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 14.0s2.0s
#                    all        250        250      0.894       0.81      0.897      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      15.7G     0.2547     0.3194      0.978         45        640: 100% ━━━━━━━━━━━━ 47/47 0.4it/s 2:072.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.5it/s 14.7s2.0s
#                    all        250        250      0.446      0.528      0.415      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      16.7G     0.2494     0.3138     0.9758         41        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:423.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.5it/s 17.1s2.2s
#                    all        250        250      0.458        0.7      0.552      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      16.7G     0.2297     0.2984     0.9653         41        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:162.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 14.4s2.0s
#                    all        250        250      0.988      0.996      0.995        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      16.7G     0.2155     0.3067     0.9594         45        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:163.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.7s1.9s
#                    all        250        250      0.958      0.996      0.994       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      15.7G     0.1983     0.2575     0.9491         44        640: 100% ━━━━━━━━━━━━ 47/47 0.4it/s 2:032.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.0s1.8s
#                    all        250        250      0.931      0.964      0.981      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      16.7G     0.1861     0.2461     0.9455         47        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:152.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.3it/s 23.3s2.3ss
#                    all        250        250      0.992      0.994      0.995       0.98
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      16.7G     0.1804     0.2397     0.9344         44        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:172.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 14.4s2.0s
#                    all        250        250      0.984       0.99      0.995      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      16.7G     0.1763     0.2402     0.9406         40        640: 100% ━━━━━━━━━━━━ 47/47 0.4it/s 2:102.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 14.1s2.0s
#                    all        250        250      0.934      0.992      0.993      0.935
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      15.7G     0.1595     0.2208      0.928         42        640: 100% ━━━━━━━━━━━━ 47/47 0.4it/s 2:082.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.8s1.9s
#                    all        250        250      0.854      0.956      0.972      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      16.7G     0.1708     0.2205     0.9317         38        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:163.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.7s2.0s
#                    all        250        250      0.916      0.961      0.958      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      16.7G     0.1616     0.2242     0.9301         50        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:312.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.7s1.9s
#                    all        250        250      0.977       0.98      0.992      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      16.7G     0.1478     0.2178      0.923         47        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:323.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.9s2.0s
#                    all        250        250       0.96          1      0.988      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      15.7G      0.137     0.1983     0.9221         38        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:203.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 12.8s1.8s
#                    all        250        250      0.992          1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      16.4G     0.1364     0.1997     0.9137         42        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:263.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.4s1.9s
#                    all        250        250      0.991          1      0.995      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      16.7G     0.1285     0.1863     0.9152         46        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:313.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.8s2.0s
#                    all        250        250      0.995      0.996      0.993      0.982
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      16.7G     0.1239     0.1866     0.9091         43        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:493.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 14.0s2.1s
#                    all        250        250      0.689      0.816      0.836      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      15.7G     0.1245     0.1907     0.9052         41        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:313.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.4s1.9s
#                    all        250        250      0.993      0.996      0.995      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      16.7G     0.1224     0.1827     0.9025         46        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:233.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.6s1.9s
#                    all        250        250      0.971      0.992       0.99       0.98
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      16.7G     0.1166     0.1762     0.9085         43        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:353.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.1s1.9s
#                    all        250        250      0.992          1      0.994      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      16.7G     0.1055     0.1636     0.9085         40        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:162.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.3s1.9s
#                    all        250        250       0.99      0.996      0.994      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      15.7G      0.109      0.166     0.9038         40        640: 100% ━━━━━━━━━━━━ 47/47 0.4it/s 2:122.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.7it/s 12.1s1.8s
#                    all        250        250       0.98          1      0.991       0.98
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      16.7G     0.1002      0.164     0.9059         37        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:273.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.7s2.0s
#                    all        250        250      0.973      0.992      0.991      0.976
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      16.7G     0.1059     0.1613     0.9039         45        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:453.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.5s1.9s
#                    all        250        250      0.954      0.992      0.972      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      16.7G     0.1048     0.1584     0.9074         41        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:333.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.4s1.9s
#                    all        250        250      0.987          1      0.993      0.985
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      15.7G    0.09623     0.1499     0.9032         45        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:232.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 12.4s1.8s
#                    all        250        250      0.996          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      16.7G    0.09677     0.1474     0.9005         51        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:413.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.2s1.9s
#                    all        250        250          1          1      0.995      0.985
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      16.7G    0.08908     0.1399     0.8976         45        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:263.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 14.3s2.0s
#                    all        250        250      0.986      0.992      0.994      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      16.7G    0.09343     0.1472     0.8932         45        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:473.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.2s1.9s
#                    all        250        250      0.992          1      0.994      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      15.7G    0.09073     0.1416     0.8948         46        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:192.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.4s1.9s
#                    all        250        250      0.996      0.999      0.992       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      16.7G    0.08746     0.1314     0.8918         44        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:242.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.2s1.9s
#                    all        250        250      0.988          1      0.995      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      16.7G    0.07872     0.1377     0.8924         40        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:202.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.4s1.9s
#                    all        250        250      0.992          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      16.7G    0.07404     0.1229     0.8885         41        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:213.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.2s1.9s
#                    all        250        250      0.996          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      15.7G    0.07657     0.1295     0.8931         46        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:203.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 12.9s1.9s
#                    all        250        250          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      16.7G     0.0747     0.1183     0.8913         45        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:373.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.1s1.9s
#                    all        250        250          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      16.7G    0.07526     0.1242      0.888         42        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:443.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.8s1.9s
#                    all        250        250      0.996          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      16.7G    0.06749     0.1138     0.8933         39        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:534.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.2s1.9s
#                    all        250        250      0.996          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      15.7G    0.06505     0.1153     0.8818         42        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:393.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.4s1.9s
#                    all        250        250          1          1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      16.7G    0.06269     0.1107     0.8888         47        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:573.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.3s1.9s
#                    all        250        250          1          1      0.995      0.993
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      16.7G    0.06781     0.2239     0.9002         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:443.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 12.8s1.9s
#                    all        250        250          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      16.7G     0.0564    0.07763     0.8993         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:423.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.0s1.9s
#                    all        250        250          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      15.7G    0.05908    0.06949     0.8861         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:373.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.7it/s 12.2s1.8s
#                    all        250        250      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      16.7G    0.05344    0.06742     0.8854         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:543.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.3s1.9s
#                    all        250        250      0.999          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      16.7G     0.0512    0.06837     0.8831         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 3:073.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.3s1.9s
#                    all        250        250          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      16.7G    0.04254    0.05816     0.8827         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:563.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.2s1.9s
#                    all        250        250          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      16.7G    0.04473    0.06353     0.8882         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:523.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.1s1.9s
#                    all        250        250          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      16.7G    0.04369    0.05598     0.8893         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:493.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.0s1.9s
#                    all        250        250          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      16.7G    0.03922    0.05079     0.8914         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 2:543.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.1s1.9s
#                    all        250        250          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      16.7G    0.03309    0.04504     0.8827         14        640: 100% ━━━━━━━━━━━━ 47/47 0.3it/s 3:024.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.6it/s 13.4s2.0s
#                    all        250        250          1          1      0.995      0.995
#
# 50 epochs completed in 2.313 hours.
# Optimizer stripped from /Users/jasonzhang/calorie_estimator/models/food101_steak/weights/last.pt, 40.5MB
# Optimizer stripped from /Users/jasonzhang/calorie_estimator/models/food101_steak/weights/best.pt, 40.5MB
#
# Validating /Users/jasonzhang/calorie_estimator/models/food101_steak/weights/best.pt...
# Ultralytics 8.3.221 🚀 Python-3.13.9 torch-2.9.0 MPS (Apple M4 Pro)
# YOLO11m summary (fused): 125 layers, 20,030,803 parameters, 0 gradients, 67.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.7it/s 11.0s.2ss
#                    all        250        250          1          1      0.995      0.995
# Speed: 0.1ms preprocess, 29.1ms inference, 0.0ms loss, 6.9ms postprocess per image
# Results saved to /Users/jasonzhang/calorie_estimator/models/food101_steak
#
# ============================================================
# Training Complete!
# ============================================================
